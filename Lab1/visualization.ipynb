# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
from datetime import datetime as dt

# %%
final = pd.read_csv('/content/final_df.csv')

# %%
final
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             0
# 1             1             1
# 2             2             2
# 3             3             3
# 4             4             4
# ..          ...           ...
# 667         667           667
# 668         668           668
# 669         669           669
# 670         670           670
# 671         671           671
#
#      0101000020E6100000202C93AD71513E4070B5CC78A7F64D40_date  \
# 0                                           1580515200
# 1                                           1580518800
# 2                                           1580522400
# 3                                           1580526000
# 4                                           1580529600
# ..                                                 ...
# 667                                         1582916400
# 668                                         1582920000
# 669                                         1582923600
# ...

# %%
final['one_date'] = [dt.fromtimestamp(x).date() for x in final['0101000020E6100000F92E3C2824663E40134E7A7396014E40_date']]

# %%
final['0101000020E6100000F92E3C2824663E40134E7A7396014E40_date']
# Out:
# 0      1580508000
# 1      1580511600
# 2      1580515200
# 3      1580518800
# 4      1580522400
#           ...
# 667    1582909200
# 668    1582912800
# 669    1582916400
# 670    1582920000
# 671    1582923600
# Name: 0101000020E6100000F92E3C2824663E40134E7A7396014E40_date, Length: 672, dtype: int64

# %%
plt.plot(final['0101000020E6100000F92E3C2824663E40134E7A7396014E40'])
plt.xlabel('Date (sorted)')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.plot(final['0101000020E61000006E409D56F8493E400A41C338F1F64D40'])
plt.xlabel('Date (sorted)')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')
